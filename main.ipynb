# %%
from nltk import bigrams, FreqDist
from nltk.tokenize import word_tokenize
import random
import unicodedata
import regex as re
import heapq
from unicodedata import normalize

# %% [markdown]
# ## Basic text prediction

# %%
# Text to work with
D = """
Niño, El sol se escondía lentamente detrás de las montañas cuando el viajero llegó al pequeño pueblo.
Las casas, construidas con piedra y madera, reflejaban la luz dorada del atardecer.
En la plaza central, los niños jugaban mientras los ancianos conversaban bajo los árboles.
El viajero se detuvo frente a una fuente antigua y observó su reflejo en el agua tranquila.
Había recorrido muchos caminos, cruzado ríos y desiertos, pero aún no había encontrado lo que buscaba.
Llevaba un mapa gastado y una brújula que apenas funcionaba.
Una mujer se acercó con una sonrisa amable y le ofreció un poco de pan.
Él agradeció el gesto y le preguntó por el camino hacia el norte.
La mujer señaló la carretera que cruzaba el valle y desaparecía entre las colinas.
El viajero respiró profundamente y siguió su marcha.
A medida que avanzaba, la noche cubría el cielo con un manto de estrellas.
Cada paso lo acercaba a su destino, aunque todavía no sabía cuál era.
El viento soplaba suave, trayendo consigo el aroma del bosque y el murmullo de los insectos.
En ese silencio, comprendió que el viaje era más importante que la llegada."""

# %%
# Convert it to lowercase, remove punctuation marks, remove accents and tokenize it
def clean_text(D):
    D = D.lower()
    s = re.sub(
        r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1", 
        normalize( "NFD", D), 0, re.I
    )

    return normalize( 'NFC', s)

D_no_accents = clean_text(D)
tokens = word_tokenize(D_no_accents)
tokens = [t for t in tokens if re.match(r'[a-zñ]+[\.\'-_]?', t)]

print(tokens)
# Out:
# ['niño', 'el', 'sol', 'se', 'escondia', 'lentamente', 'detras', 'de', 'las', 'montañas', 'cuando', 'el', 'viajero', 'llego', 'al', 'pequeño', 'pueblo', 'las', 'casas', 'construidas', 'con', 'piedra', 'y', 'madera', 'reflejaban', 'la', 'luz', 'dorada', 'del', 'atardecer', 'en', 'la', 'plaza', 'central', 'los', 'niños', 'jugaban', 'mientras', 'los', 'ancianos', 'conversaban', 'bajo', 'los', 'arboles', 'el', 'viajero', 'se', 'detuvo', 'frente', 'a', 'una', 'fuente', 'antigua', 'y', 'observo', 'su', 'reflejo', 'en', 'el', 'agua', 'tranquila', 'habia', 'recorrido', 'muchos', 'caminos', 'cruzado', 'rios', 'y', 'desiertos', 'pero', 'aun', 'no', 'habia', 'encontrado', 'lo', 'que', 'buscaba', 'llevaba', 'un', 'mapa', 'gastado', 'y', 'una', 'brujula', 'que', 'apenas', 'funcionaba', 'una', 'mujer', 'se', 'acerco', 'con', 'una', 'sonrisa', 'amable', 'y', 'le', 'ofrecio', 'un', 'poco', 'de', 'pan', 'el', 'agradecio', 'el', 'gesto', 'y', 'le', 'pregunto', 'por', 'el', 'camino', 'hacia', 'el', 'norte', 'la', 'mujer', 'señalo', 'la', 'carretera', 'que', 'cruzaba', 'el', 'valle', 'y', 'desaparecia', 'entre', 'las', 'colinas', 'el', 'viajero', 'respiro', 'profundamente', 'y', 'siguio', 'su', 'marcha', 'a', 'medida', 'que', 'avanzaba', 'la', 'noche', 'cubria', 'el', 'cielo', 'con', 'un', 'manto', 'de', 'estrellas', 'cada', 'paso', 'lo', 'acercaba', 'a', 'su', 'destino', 'aunque', 'todavia', 'no', 'sabia', 'cual', 'era', 'el', 'viento', 'soplaba', 'suave', 'trayendo', 'consigo', 'el', 'aroma', 'del', 'bosque', 'y', 'el', 'murmullo', 'de', 'los', 'insectos', 'en', 'ese', 'silencio', 'comprendio', 'que', 'el', 'viaje', 'era', 'mas', 'importante', 'que', 'la', 'llegada']

# %%
bigrams_list = list(bigrams(tokens))
print(bigrams_list)

words_frequency = FreqDist(tokens)
print(words_frequency.items())

bigrams_frequency = FreqDist(bigrams_list)
print(bigrams_frequency.items())
print(bigrams_frequency.most_common(5))
# Out:
# [('niño', 'el'), ('el', 'sol'), ('sol', 'se'), ('se', 'escondia'), ('escondia', 'lentamente'), ('lentamente', 'detras'), ('detras', 'de'), ('de', 'las'), ('las', 'montañas'), ('montañas', 'cuando'), ('cuando', 'el'), ('el', 'viajero'), ('viajero', 'llego'), ('llego', 'al'), ('al', 'pequeño'), ('pequeño', 'pueblo'), ('pueblo', 'las'), ('las', 'casas'), ('casas', 'construidas'), ('construidas', 'con'), ('con', 'piedra'), ('piedra', 'y'), ('y', 'madera'), ('madera', 'reflejaban'), ('reflejaban', 'la'), ('la', 'luz'), ('luz', 'dorada'), ('dorada', 'del'), ('del', 'atardecer'), ('atardecer', 'en'), ('en', 'la'), ('la', 'plaza'), ('plaza', 'central'), ('central', 'los'), ('los', 'niños'), ('niños', 'jugaban'), ('jugaban', 'mientras'), ('mientras', 'los'), ('los', 'ancianos'), ('ancianos', 'conversaban'), ('conversaban', 'bajo'), ('bajo', 'los'), ('los', 'arboles'), ('arboles', 'el'), ('el', 'viajero'), ('viajero', 'se'), ('se', 'detuvo'), ('detuvo', 'frente'), ('frente', 'a'), ('a', 'una'), ('una', 'fuente'), ('fuente', 'antigua'), ('antigua', 'y'), ('y', 'observo'), ('observo', 'su'), ('su', 'reflejo'), ('reflejo', 'en'), ('en', 'el'), ('el', 'agua'), ('agua', 'tranquila'), ('tranquila', 'habia'), ('habia', 'recorrido'), ('recorrido', 'muchos'), ('muchos', 'caminos'), ('caminos', 'cruzado'), ('cruzado', 'rios'), ('rios', 'y'), ('y', 'desiertos'), ('desiertos', 'pero'), ('pero', 'aun'), ('aun', 'no'), ('no', 'habia'), ('habia', 'encontrado'), ('encontrado', 'lo'), ('lo', 'que'), ('que', 'buscaba'), ('buscaba', 'llevaba'), ('llevaba', 'un'), ('un', 'mapa'), ('mapa', 'gastado'), ('gastado', 'y'), ('y', 'una'), ('una', 'brujula'), ('brujula', 'que'), ('que', 'apenas'), ('apenas', 'funcionaba'), ('funcionaba', 'una'), ('una', 'mujer'), ('mujer', 'se'), ('se', 'acerco'), ('acerco', 'con'), ('con', 'una'), ('una', 'sonrisa'), ('sonrisa', 'amable'), ('amable', 'y'), ('y', 'le'), ('le', 'ofrecio'), ('ofrecio', 'un'), ('un', 'poco'), ('poco', 'de'), ('de', 'pan'), ('pan', 'el'), ('el', 'agradecio'), ('agradecio', 'el'), ('el', 'gesto'), ('gesto', 'y'), ('y', 'le'), ('le', 'pregunto'), ('pregunto', 'por'), ('por', 'el'), ('el', 'camino'), ('camino', 'hacia'), ('hacia', 'el'), ('el', 'norte'), ('norte', 'la'), ('la', 'mujer'), ('mujer', 'señalo'), ('señalo', 'la'), ('la', 'carretera'), ('carretera', 'que'), ('que', 'cruzaba'), ('cruzaba', 'el'), ('el', 'valle'), ('valle', 'y'), ('y', 'desaparecia'), ('desaparecia', 'entre'), ('entre', 'las'), ('las', 'colinas'), ('colinas', 'el'), ('el', 'viajero'), ('viajero', 'respiro'), ('respiro', 'profundamente'), ('profundamente', 'y'), ('y', 'siguio'), ('siguio', 'su'), ('su', 'marcha'), ('marcha', 'a'), ('a', 'medida'), ('medida', 'que'), ('que', 'avanzaba'), ('avanzaba', 'la'), ('la', 'noche'), ('noche', 'cubria'), ('cubria', 'el'), ('el', 'cielo'), ('cielo', 'con'), ('con', 'un'), ('un', 'manto'), ('manto', 'de'), ('de', 'estrellas'), ('estrellas', 'cada'), ('cada', 'paso'), ('paso', 'lo'), ('lo', 'acercaba'), ('acercaba', 'a'), ('a', 'su'), ('su', 'destino'), ('destino', 'aunque'), ('aunque', 'todavia'), ('todavia', 'no'), ('no', 'sabia'), ('sabia', 'cual'), ('cual', 'era'), ('era', 'el'), ('el', 'viento'), ('viento', 'soplaba'), ('soplaba', 'suave'), ('suave', 'trayendo'), ('trayendo', 'consigo'), ('consigo', 'el'), ('el', 'aroma'), ('aroma', 'del'), ('del', 'bosque'), ('bosque', 'y'), ('y', 'el'), ('el', 'murmullo'), ('murmullo', 'de'), ('de', 'los'), ('los', 'insectos'), ('insectos', 'en'), ('en', 'ese'), ('ese', 'silencio'), ('silencio', 'comprendio'), ('comprendio', 'que'), ('que', 'el'), ('el', 'viaje'), ('viaje', 'era'), ('era', 'mas'), ('mas', 'importante'), ('importante', 'que'), ('que', 'la'), ('la', 'llegada')]
# dict_items([('niño', 1), ('el', 15), ('sol', 1), ('se', 3), ('escondia', 1), ('lentamente', 1), ('detras', 1), ('de', 4), ('las', 3), ('montañas', 1), ('cuando', 1), ('viajero', 3), ('llego', 1), ('al', 1), ('pequeño', 1), ('pueblo', 1), ('casas', 1), ('construidas', 1), ('con', 3), ('piedra', 1), ('y', 9), ('madera', 1), ('reflejaban', 1), ('la', 6), ('luz', 1), ('dorada', 1), ('del', 2), ('atardecer', 1), ('en', 3), ('plaza', 1), ('central', 1), ('los', 4), ('niños', 1), ('jugaban', 1), ('mientras', 1), ('ancianos', 1), ('conversaban', 1), ('bajo', 1), ('arboles', 1), ('detuvo', 1), ('frente', 1), ('a', 3), ('una', 4), ('fuente', 1), ('antigua', 1), ('observo', 1), ('su', 3), ('reflejo', 1), ('agua', 1), ('tranquila', 1), ('habia', 2), ('recorrido', 1), ('muchos', 1), ('caminos', 1), ('cruzado', 1), ('rios', 1), ('desiertos', 1), ('pero', 1), ('aun', 1), ('no', 2), ('encontrado', 1), ('lo', 2), ('que', 6), ('buscaba', 1), ('llevaba', 1), ('un', 3), ('mapa', 1), ('gastado', 1), ('brujula', 1), ('apenas', 1), ('funcionaba', 1), ('mujer', 2), ('acerco', 1), ('sonrisa', 1), ('amable', 1), ('le', 2), ('ofrecio', 1), ('poco', 1), ('pan', 1), ('agradecio', 1), ('gesto', 1), ('pregunto', 1), ('por', 1), ('camino', 1), ('hacia', 1), ('norte', 1), ('señalo', 1), ('carretera', 1), ('cruzaba', 1), ('valle', 1), ('desaparecia', 1), ('entre', 1), ('colinas', 1), ('respiro', 1), ('profundamente', 1), ('siguio', 1), ('marcha', 1), ('medida', 1), ('avanzaba', 1), ('noche', 1), ('cubria', 1), ('cielo', 1), ('manto', 1), ('estrellas', 1), ('cada', 1), ('paso', 1), ('acercaba', 1), ('destino', 1), ('aunque', 1), ('todavia', 1), ('sabia', 1), ('cual', 1), ('era', 2), ('viento', 1), ('soplaba', 1), ('suave', 1), ('trayendo', 1), ('consigo', 1), ('aroma', 1), ('bosque', 1), ('murmullo', 1), ('insectos', 1), ('ese', 1), ('silencio', 1), ('comprendio', 1), ('viaje', 1), ('mas', 1), ('importante', 1), ('llegada', 1)])
# dict_items([(('niño', 'el'), 1), (('el', 'sol'), 1), (('sol', 'se'), 1), (('se', 'escondia'), 1), (('escondia', 'lentamente'), 1), (('lentamente', 'detras'), 1), (('detras', 'de'), 1), (('de', 'las'), 1), (('las', 'montañas'), 1), (('montañas', 'cuando'), 1), (('cuando', 'el'), 1), (('el', 'viajero'), 3), (('viajero', 'llego'), 1), (('llego', 'al'), 1), (('al', 'pequeño'), 1), (('pequeño', 'pueblo'), 1), (('pueblo', 'las'), 1), (('las', 'casas'), 1), (('casas', 'construidas'), 1), (('construidas', 'con'), 1), (('con', 'piedra'), 1), (('piedra', 'y'), 1), (('y', 'madera'), 1), (('madera', 'reflejaban'), 1), (('reflejaban', 'la'), 1), (('la', 'luz'), 1), (('luz', 'dorada'), 1), (('dorada', 'del'), 1), (('del', 'atardecer'), 1), (('atardecer', 'en'), 1), (('en', 'la'), 1), (('la', 'plaza'), 1), (('plaza', 'central'), 1), (('central', 'los'), 1), (('los', 'niños'), 1), (('niños', 'jugaban'), 1), (('jugaban', 'mientras'), 1), (('mientras', 'los'), 1), (('los', 'ancianos'), 1), (('ancianos', 'conversaban'), 1), (('conversaban', 'bajo'), 1), (('bajo', 'los'), 1), (('los', 'arboles'), 1), (('arboles', 'el'), 1), (('viajero', 'se'), 1), (('se', 'detuvo'), 1), (('detuvo', 'frente'), 1), (('frente', 'a'), 1), (('a', 'una'), 1), (('una', 'fuente'), 1), (('fuente', 'antigua'), 1), (('antigua', 'y'), 1), (('y', 'observo'), 1), (('observo', 'su'), 1), (('su', 'reflejo'), 1), (('reflejo', 'en'), 1), (('en', 'el'), 1), (('el', 'agua'), 1), (('agua', 'tranquila'), 1), (('tranquila', 'habia'), 1), (('habia', 'recorrido'), 1), (('recorrido', 'muchos'), 1), (('muchos', 'caminos'), 1), (('caminos', 'cruzado'), 1), (('cruzado', 'rios'), 1), (('rios', 'y'), 1), (('y', 'desiertos'), 1), (('desiertos', 'pero'), 1), (('pero', 'aun'), 1), (('aun', 'no'), 1), (('no', 'habia'), 1), (('habia', 'encontrado'), 1), (('encontrado', 'lo'), 1), (('lo', 'que'), 1), (('que', 'buscaba'), 1), (('buscaba', 'llevaba'), 1), (('llevaba', 'un'), 1), (('un', 'mapa'), 1), (('mapa', 'gastado'), 1), (('gastado', 'y'), 1), (('y', 'una'), 1), (('una', 'brujula'), 1), (('brujula', 'que'), 1), (('que', 'apenas'), 1), (('apenas', 'funcionaba'), 1), (('funcionaba', 'una'), 1), (('una', 'mujer'), 1), (('mujer', 'se'), 1), (('se', 'acerco'), 1), (('acerco', 'con'), 1), (('con', 'una'), 1), (('una', 'sonrisa'), 1), (('sonrisa', 'amable'), 1), (('amable', 'y'), 1), (('y', 'le'), 2), (('le', 'ofrecio'), 1), (('ofrecio', 'un'), 1), (('un', 'poco'), 1), (('poco', 'de'), 1), (('de', 'pan'), 1), (('pan', 'el'), 1), (('el', 'agradecio'), 1), (('agradecio', 'el'), 1), (('el', 'gesto'), 1), (('gesto', 'y'), 1), (('le', 'pregunto'), 1), (('pregunto', 'por'), 1), (('por', 'el'), 1), (('el', 'camino'), 1), (('camino', 'hacia'), 1), (('hacia', 'el'), 1), (('el', 'norte'), 1), (('norte', 'la'), 1), (('la', 'mujer'), 1), (('mujer', 'señalo'), 1), (('señalo', 'la'), 1), (('la', 'carretera'), 1), (('carretera', 'que'), 1), (('que', 'cruzaba'), 1), (('cruzaba', 'el'), 1), (('el', 'valle'), 1), (('valle', 'y'), 1), (('y', 'desaparecia'), 1), (('desaparecia', 'entre'), 1), (('entre', 'las'), 1), (('las', 'colinas'), 1), (('colinas', 'el'), 1), (('viajero', 'respiro'), 1), (('respiro', 'profundamente'), 1), (('profundamente', 'y'), 1), (('y', 'siguio'), 1), (('siguio', 'su'), 1), (('su', 'marcha'), 1), (('marcha', 'a'), 1), (('a', 'medida'), 1), (('medida', 'que'), 1), (('que', 'avanzaba'), 1), (('avanzaba', 'la'), 1), (('la', 'noche'), 1), (('noche', 'cubria'), 1), (('cubria', 'el'), 1), (('el', 'cielo'), 1), (('cielo', 'con'), 1), (('con', 'un'), 1), (('un', 'manto'), 1), (('manto', 'de'), 1), (('de', 'estrellas'), 1), (('estrellas', 'cada'), 1), (('cada', 'paso'), 1), (('paso', 'lo'), 1), (('lo', 'acercaba'), 1), (('acercaba', 'a'), 1), (('a', 'su'), 1), (('su', 'destino'), 1), (('destino', 'aunque'), 1), (('aunque', 'todavia'), 1), (('todavia', 'no'), 1), (('no', 'sabia'), 1), (('sabia', 'cual'), 1), (('cual', 'era'), 1), (('era', 'el'), 1), (('el', 'viento'), 1), (('viento', 'soplaba'), 1), (('soplab ...
# [(('el', 'viajero'), 3), (('y', 'le'), 2), (('niño', 'el'), 1), (('el', 'sol'), 1), (('sol', 'se'), 1)]

# %%
# Probability of each bigram
bigrams_probs = []

bigrams_frequency = list(bigrams_frequency.items())

words_frequency = list(words_frequency.items())
words_frequency = dict(words_frequency)

for i, freq in enumerate(bigrams_frequency):
    tup, freq = freq
    word = tup[0]
    word_freq = words_frequency[word]
    bigrams_probs.append((tup, freq/word_freq))

print(bigrams_probs)
# Out:
# [(('niño', 'el'), 1.0), (('el', 'sol'), 0.06666666666666667), (('sol', 'se'), 1.0), (('se', 'escondia'), 0.3333333333333333), (('escondia', 'lentamente'), 1.0), (('lentamente', 'detras'), 1.0), (('detras', 'de'), 1.0), (('de', 'las'), 0.25), (('las', 'montañas'), 0.3333333333333333), (('montañas', 'cuando'), 1.0), (('cuando', 'el'), 1.0), (('el', 'viajero'), 0.2), (('viajero', 'llego'), 0.3333333333333333), (('llego', 'al'), 1.0), (('al', 'pequeño'), 1.0), (('pequeño', 'pueblo'), 1.0), (('pueblo', 'las'), 1.0), (('las', 'casas'), 0.3333333333333333), (('casas', 'construidas'), 1.0), (('construidas', 'con'), 1.0), (('con', 'piedra'), 0.3333333333333333), (('piedra', 'y'), 1.0), (('y', 'madera'), 0.1111111111111111), (('madera', 'reflejaban'), 1.0), (('reflejaban', 'la'), 1.0), (('la', 'luz'), 0.16666666666666666), (('luz', 'dorada'), 1.0), (('dorada', 'del'), 1.0), (('del', 'atardecer'), 0.5), (('atardecer', 'en'), 1.0), (('en', 'la'), 0.3333333333333333), (('la', 'plaza'), 0.16666666666666666), (('plaza', 'central'), 1.0), (('central', 'los'), 1.0), (('los', 'niños'), 0.25), (('niños', 'jugaban'), 1.0), (('jugaban', 'mientras'), 1.0), (('mientras', 'los'), 1.0), (('los', 'ancianos'), 0.25), (('ancianos', 'conversaban'), 1.0), (('conversaban', 'bajo'), 1.0), (('bajo', 'los'), 1.0), (('los', 'arboles'), 0.25), (('arboles', 'el'), 1.0), (('viajero', 'se'), 0.3333333333333333), (('se', 'detuvo'), 0.3333333333333333), (('detuvo', 'frente'), 1.0), (('frente', 'a'), 1.0), (('a', 'una'), 0.3333333333333333), (('una', 'fuente'), 0.25), (('fuente', 'antigua'), 1.0), (('antigua', 'y'), 1.0), (('y', 'observo'), 0.1111111111111111), (('observo', 'su'), 1.0), (('su', 'reflejo'), 0.3333333333333333), (('reflejo', 'en'), 1.0), (('en', 'el'), 0.3333333333333333), (('el', 'agua'), 0.06666666666666667), (('agua', 'tranquila'), 1.0), (('tranquila', 'habia'), 1.0), (('habia', 'recorrido'), 0.5), (('recorrido', 'muchos'), 1.0), (('muchos', 'caminos'), 1.0), (('caminos', 'cruzado'), 1.0), (('cruzado', 'rios'), 1.0), (('rios', 'y'), 1.0), (('y', 'desiertos'), 0.1111111111111111), (('desiertos', 'pero'), 1.0), (('pero', 'aun'), 1.0), (('aun', 'no'), 1.0), (('no', 'habia'), 0.5), (('habia', 'encontrado'), 0.5), (('encontrado', 'lo'), 1.0), (('lo', 'que'), 0.5), (('que', 'buscaba'), 0.16666666666666666), (('buscaba', 'llevaba'), 1.0), (('llevaba', 'un'), 1.0), (('un', 'mapa'), 0.3333333333333333), (('mapa', 'gastado'), 1.0), (('gastado', 'y'), 1.0), (('y', 'una'), 0.1111111111111111), (('una', 'brujula'), 0.25), (('brujula', 'que'), 1.0), (('que', 'apenas'), 0.16666666666666666), (('apenas', 'funcionaba'), 1.0), (('funcionaba', 'una'), 1.0), (('una', 'mujer'), 0.25), (('mujer', 'se'), 0.5), (('se', 'acerco'), 0.3333333333333333), (('acerco', 'con'), 1.0), (('con', 'una'), 0.3333333333333333), (('una', 'sonrisa'), 0.25), (('sonrisa', 'amable'), 1.0), (('amable', 'y'), 1.0), (('y', 'le'), 0.2222222222222222), (('le', 'ofrecio'), 0.5), (('ofrecio', 'un'), 1.0), (('un', 'poco'), 0.3333333333333333), (('poco', 'de'), 1.0), (('de', 'pan'), 0.25), (('pan', 'el'), 1.0), (('el', 'agradecio'), 0.06666666666666667), (('agradecio', 'el'), 1.0), (('el', 'gesto'), 0.06666666666666667), (('gesto', 'y'), 1.0), (('le', 'pregunto'), 0.5), (('pregunto', 'por'), 1.0), (('por', 'el'), 1.0), (('el', 'camino'), 0.06666666666666667), (('camino', 'hacia'), 1.0), (('hacia', 'el'), 1.0), (('el', 'norte'), 0.06666666666666667), (('norte', 'la'), 1.0), (('la', 'mujer'), 0.16666666666666666), (('mujer', 'señalo'), 0.5), (('señalo', 'la'), 1.0), (('la', 'carretera'), 0.16666666666666666), (('carretera', 'que'), 1.0), (('que', 'cruzaba'), 0.16666666666666666), (('cruzaba', 'el'), 1.0), (('el', 'valle'), 0.06666666666666667), (('valle', 'y'), 1.0), (('y', 'desaparecia'), 0.1111111111111111), (('desaparecia', 'entre'), 1.0), (('entre', 'las'), 1.0), (('las', 'colinas'), 0.3333333333333333), (('colinas', 'el'), 1.0), (('viajero', 'respiro'), 0.3333333333333333), (('respiro', 'profundamen ...

# %%
# Next word prediction
def predict_next_word(actual_word):
    actual_word = clean_text(actual_word)
    actual_word = actual_word.lower()
    words = []
    for bigram in bigrams_probs:
        if actual_word == bigram[0][0]:
            words.append((bigram[0][1], bigram[1]))
    
    return heapq.nlargest(3, words, key=lambda x: x[1])

print(predict_next_word("tu"))
# Out:
# []

# %%
# Generate text
def generate_text(word, len=15):
    word = clean_text(word)
    text = word
    for i in range(len):
        next_word = random.choice(predict_next_word(word))[0]
        text += f" {next_word}"
        word = next_word
        
    return text

print(generate_text("El"))
# Out:
# el sol se acerco con piedra y madera reflejaban la luz dorada del atardecer en la
